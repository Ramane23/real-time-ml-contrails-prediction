# %%
import pandas as pd
import duckdb
# Connect to DuckDB (it will create an in-memory database)
conn = duckdb.connect()
#load the transformed dataset
df_transformed = pd.read_csv('../files/flights_data_with_features.csv', index_col=0)
print(f'there are {df_transformed.shape[0]} rows and {df_transformed.shape[1]} columns in the dataset')
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df_transformed.head(3))
# Out:
# there are 92000 rows and 173 columns in the dataset
#                                  route  departure_airport_lat  \
# current_flight_time
# 2024-09-10 07:50:00      Oslo - Bergen              60.121000
# 2024-09-10 07:58:00  Paris - Marseille              48.723333
# 2024-09-10 07:59:00     Catania - Rome              37.466801
#
#                      departure_airport_long  arrival_airport_lat  \
# current_flight_time
# 2024-09-10 07:50:00               11.050200            60.293400
# 2024-09-10 07:58:00                2.379444            43.439272
# 2024-09-10 07:59:00               15.066400            41.800278
#
#                      arrival_airport_long  altitude  latitude  longitude  \
# current_flight_time
# 2024-09-10 07:50:00              5.218140    396.24   60.3338     5.2045
# 2024-09-10 07:58:00              5.221424   5181.60   44.3416     4.8195
# 2024-09-10 07:59:00             12.238889    990.60   41.5612    12.3803
#
# ...

# %% [markdown]
# CROSS-JOINS
#
# Question: Create a detailed table showing all possible combinations between flight_id and contrail_formation probability from the weather_data table to analyze contrail scenarios for each flight.

# %%
querry = """ """
# Query the DataFrame using SQL
result = conn.execute(querry).fetchall()

print(result)
