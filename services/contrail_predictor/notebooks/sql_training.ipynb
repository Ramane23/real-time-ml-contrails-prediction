# %%
import pandas as pd
import duckdb
# Connect to DuckDB (it will create an in-memory database)
conn = duckdb.connect()
#load the transformed dataset
df_transformed = pd.read_csv('../files/flights_data_preprocessed.csv', index_col=0)
print(f'there are {df_transformed.shape[0]} rows and {df_transformed.shape[1]} columns in the dataset')
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df_transformed.head(3))
# Out:
# there are 1062682 rows and 34 columns in the dataset
#                     flight_id            route aircraft_type  \
# current_flight_time
# 2024-09-14 19:04:00     5M132  Madrid - Malaga          AT76
# 2024-09-14 19:05:00     5M132  Madrid - Malaga          AT76
# 2024-09-14 19:06:00     5M132  Madrid - Malaga          AT76
#
#                      aircraft_mtow_kg  aircraft_malw_kg aircraft_engine_class  \
# current_flight_time
# 2024-09-14 19:04:00       22799.80188      22349.838616             Turboprop
# 2024-09-14 19:05:00       22799.80188      22349.838616             Turboprop
# 2024-09-14 19:06:00       22799.80188      22349.838616             Turboprop
#
#                      aircraft_num_engines  mach_number  true_airspeed_ms  \
# current_flight_time
# 2024-09-14 19:04:00                   2.0     1.110544           362.992
# 2024-09-14 19:05:00                   2.0     1.134786           371.326
# 2024-09-14 19:06:00                   2.0     1.159027           379.660
#
#                      altitude flight_level   latitude  longitude  \
# current_flight_time
# 2024-09-14 19:04:00   3284.22        FL108  40.575800  -3.743700
# 2024-09-14 19:05:00   3284.22        FL108  40.528283  -3.725733
# 2024-09-14 19:06:00   3284.22        FL108  40.480767  -3.707767
#
#                      horizontal_speed  vertical_speed flight_phase  \
# current_flight_time
# 2024-09-14 19:04:00           362.992             0.0       cruise
# 2024-09-14 19:05:00           371.326             0.0       cruise
# 2024-09-14 19:06:00           379.660             0.0       cruise
#
#                      temperature_c  pressure_hpa  wind_speed_u_ms  \
# current_flight_time
# 2024-09-14 19:04:00           -7.3         555.0              7.4
# 2024-09-14 19:05:00           -7.3         555.0              6.5
# 2024-09-14 19:06:00           -7.3         555.0              5.6
#
#                      wind_speed_v_ms  wind_speed_ms  geopotential_height_m  \
# current_flight_time
# 2024-09-14 19:04:00           -17.00      18.540766                 5404.6
# 2024-09-14 19:05:00           -14.65      16.037769                 5404.6
# 2024-09-14 19:06:00           -12.30      13.534772                 5404.6
#
#                      relative_humidity_percent  specific_humidity_kg_kg  \
# current_flight_time
# 2024-09-14 19:04:00                       12.1                  0.00048
# 2024-09-14 19:05:00                       12.1                  0.00048
# 2024-09-14 19:06:00                       12.1                  0.00048
#
#                      total_cloud_cover_octas  high_cloud_cover_octas  \
# current_flight_time
# 2024-09-14 19:04:00                      0.0                     0.0
# 2024-09-14 19:05:00                      0.0                     0.0
# 2024-09-14 19:06:00                      0.0                     0.0
#
#                      global_radiation_w_m2  prob_contrails_percent  direction  \
# current_flight_time
# 2024-09-14 19:04:00                  220.9                     0.0      126.0
# 2024-09-14 19:05:00                  220.9                     0.0      136.0
# 2024-09-14 19:06:00                  220.9                     0.0      146.0
#
#                      departure_airport_lat  arrival_airport_lat  \
# current_flight_time
# 2024-09-14 19:04:00              40.471926              36.6749
# 2024-09-14 19:05:00              40.471926              36.6749
# 2024-09-14 19:06:00              40.471926              36.6749
#
#                      departure_airport_long  arrival_airport_long  \
# current_flight_time
# 2024-09-14 19:04:00                -3.56264              -4.49911
# 2024-09-14 19:05:00                -3.56264              -4.49911
# 2024-09-14 19:06:00                -3.56264              -4.49911
#
#                      contrail_formation
# current_flight_time
# 2024-09-14 19:04:00                   0
# 2024-09-14 19:05:00                   0
# 2024-09-14 19:06:00                   0

# %% [markdown]
# CROSS-JOINS
#
# Question: Create a detailed table showing all possible combinations between flight_id and contrail_formation probability from the weather_data table to analyze contrail scenarios for each flight.

# %%
querry = """ """
# Query the DataFrame using SQL
result = conn.execute(querry).fetchall()

print(result)
